# %%
import pandas as pd

df = pd.read_csv("../Data/cleaned/cleaned_taxi_data.csv")

# %%
df_sample = df.sample(200000, random_state=42)

# %%
df_sample
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 4527615         1  2015-01-20 01:48:49   2015-01-20 01:59:43                1
# 5928050         1  2015-01-28 09:01:53   2015-01-28 09:27:04                4
# 5979044         1  2015-01-25 03:03:38   2015-01-25 03:13:52                1
# 6801811         1  2015-01-13 07:18:21   2015-01-13 07:21:52                1
# 7086433         1  2015-01-03 04:11:41   2015-01-03 04:17:33                1
# ...           ...                  ...                   ...              ...
# 1845948         2  2015-01-01 02:19:10   2015-01-01 02:25:31                2
# 6226597         2  2015-01-29 15:13:41   2015-01-29 15:23:40                2
# 5513977         2  2015-01-25 12:59:10   2015-01-25 13:00:28                5
# 1280624         2  2015-01-28 06:31:40   2015-01-28 06:35:37                1
# 7257139         2  2015-01-08 21:56:54   2015-01-08 22:10:33                5
#
# ...

# %%
print(df.shape)
df.head()
# Out:
# (7311564, 23)
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111         1.0
# 1           3.30        -74.001648        40.724243         1.0
# 2           1.80        -73.963341        40.802788         1.0
# 3           0.50        -74.009087        40.713818         1.0
# 4           3.00        -73.971176        40.762428         1.0
#
#   store_and_fwd_flag  dropoff_longitude  ...  extra  mta_tax  tip_amount  \
# ...

# %% [markdown]
# Trip Distance ->

# %%
sns.histplot(df_sample['trip_distance'], bins=50)
plt.title("Trip Distance Distribution")
plt.show()

# %% [markdown]
# Trip Duration ->

# %%
sns.histplot(df_sample['trip_duration'], bins=50)
plt.title("Trip Duration Distribution (minutes)")
plt.show()

# %% [markdown]
# Fare Distribution ->

# %%
sns.histplot(df_sample['fare_amount'], bins=50)
plt.title("Fare Distribution")
plt.show()

# %% [markdown]
# Fare vs Distance

# %%
sns.scatterplot(
    x='trip_distance',
    y='fare_amount',
    data=df_sample,
    alpha=0.7
)
plt.title("Fare vs Distance")
plt.show()

# %%
sns.histplot(df_sample['tip_amount'], bins=50)
plt.title("Tip Distribution")
plt.show()

# %%
df_sample['pickup_hour'].value_counts().sort_index().plot(kind='bar')
plt.title("Trips by Hour")
plt.show()

# %%
df_sample['day_of_week'].value_counts().plot(kind='bar')
plt.title("Trips by Day")
plt.show()

# %%
sns.scatterplot(
    x='pickup_longitude',
    y='pickup_latitude',
    data=df_sample,
    alpha=0.9
)
plt.title("Pickup Locations")
plt.show()

# %%
corr = df_sample[
    ['trip_distance','fare_amount','trip_duration','passenger_count','tip_amount']
].corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Tips vs Payment Type ->

# %%
sns.boxplot(
    x='payment_type',
    y='tip_amount',
    data=df_sample
)
plt.title("Tips by Payment Type")
plt.show()
